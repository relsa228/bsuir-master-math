# %% [markdown]
# # Лабораторная работа №4. Реализация приложения по распознаванию номеров домов

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
import h5py
import numpy as np
from scipy.io import loadmat
import gc
# Out:
# 2025-05-18 01:11:29.402792: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-18 01:11:29.410862: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-18 01:11:29.464386: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-18 01:11:29.519352: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747519889.567871    2484 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747519889.583145    2484 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747519889.675226    2484 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747519889.675262    2484 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747519889.675264    2484 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747519889.675266    2484 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-18 01:11:29.690432: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Загрузим данные `MNIST`, нормализуем их и разделим на тренировочный и тестовый набор

# %% [markdown]
# Загрузка данных

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# %% [markdown]
# Одной из самых популярных из современных архитектур моделей для распознавания изображений является `ResNet`. Эта сеть позволяет передавать информацию между слоями, сохраняя полезные данные.

# %% [raw]
# Отличительной особенностью данной модели является использование в обучении остаточных блоков, где входные данные проходят через несколько сверточных слоев и затем суммируются с исходным сигналом.
#
# ![alt](https://upload.wikimedia.org/wikipedia/commons/b/ba/ResBlock.png)

# %%
def residual_block(x, filters, downsample=False):
    shortcut = x
    strides = 2 if downsample else 1

    x = layers.Conv2D(filters, (3, 3), strides=strides, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(filters, (3, 3), padding="same")(x)
    x = layers.BatchNormalization()(x)

    if downsample or x.shape[-1] != shortcut.shape[-1]:
        shortcut = layers.Conv2D(filters, (1, 1), strides=strides, padding="same")(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([x, shortcut])
    x = layers.Activation("relu")(x)
    return x

# %% [markdown]
# Упростим функцию пропуска блока для работы на мобильных устройствах

# %%
def residual_block_light(x, filters):
    shortcut = layers.Conv2D(filters, (1, 1), padding="same")(x)
    x = layers.Conv2D(filters, (3, 3), padding="same", activation="relu")(x)
    x = layers.Conv2D(filters, (3, 3), padding="same")(x)
    x = layers.Add()([x, shortcut])
    x = layers.Activation("relu")(x)
    return x

# %% [markdown]
# Построим облегченную версию `ResNet`, которая подойдет для работы с мобильными устройствами

# %%
inputs = keras.Input(shape=(28, 28, 1))  # 28×28 черно-белые изображения
x = layers.Conv2D(16, (3, 3), activation="relu", padding="same")(inputs)
x = residual_block_light(x, 16)
x = layers.MaxPooling2D((2, 2))(x)

x = residual_block(x, 32)
x = layers.MaxPooling2D((2, 2))(x)

x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(32, activation="relu")(x)
x = layers.Dense(10, activation="softmax")(x)  # 10 классов цифр

model = keras.Model(inputs, x)

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# 2025-05-18 01:11:34.257389: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 28, 28, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 28, 28,    │        160 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 28, 28,    │      2,320 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 28, 28,    │      2,320 │ conv2d_2[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 28, 28,    │        272 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 28, 28,    │          0 │ conv2d_3[0][0],   │
# │                     │ 16)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 28, 28,    │          0 │ add[0][0]         │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 14, 14,    │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 14, 14,    │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 14, 14,    │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 14, 14,    │      9,248 │ activation_1[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 14, 14,    │        544 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        128 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 14, 14,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 7, 7, 32)  │          0 │ activation_2[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ max_pooling2d_1[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │      1,056 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 10)        │        330 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 21,274 (83.10 KB)
#  Trainable params: 21,082 (82.35 KB)
#  Non-trainable params: 192 (768.00 B)

# %% [markdown]
# Обучим и протестируем модель

# %%
model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test))
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Точность модели на тестовых данных: {test_acc:.4f}')
# Out:
# Epoch 1/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7727 - loss: 0.8010 - val_accuracy: 0.9451 - val_loss: 0.1728
# Epoch 2/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9749 - loss: 0.0861 - val_accuracy: 0.8060 - val_loss: 0.5694
# Epoch 3/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.9819 - loss: 0.0591 - val_accuracy: 0.9810 - val_loss: 0.0603
# Epoch 4/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9845 - loss: 0.0492 - val_accuracy: 0.9219 - val_loss: 0.2509
# Epoch 5/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9870 - loss: 0.0424 - val_accuracy: 0.9689 - val_loss: 0.0953
# Epoch 6/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9890 - loss: 0.0360 - val_accuracy: 0.9755 - val_loss: 0.0802
# Epoch 7/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9899 - loss: 0.0327 - val_accuracy: 0.9839 - val_loss: 0.0477
# Epoch 8/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9904 - loss: 0.0311 - val_accuracy: 0.9839 - val_loss: 0.0534
# Epoch 9/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9912 - loss: 0.0280 - val_accuracy: 0.9793 - val_loss: 0.0668
# Epoch 10/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9923 - loss: 0.0263 - val_accuracy: 0.9857 - val_loss: 0.0562
# Epoch 11/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9917 - loss: 0.0251 - val_accuracy: 0.9754 - val_loss: 0.0834
# Epoch 12/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9933 - loss: 0.0216 - val_accuracy: 0.9675 - val_loss: 0.1122
# Epoch 13/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9933 - loss: 0.0212 - val_accuracy: 0.9830 - val_loss: 0.0617
# Epoch 14/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9940 - loss: 0.0194 - val_accuracy: 0.9878 - val_loss: 0.0403
# Epoch 15/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9940 - loss: 0.0186 - val_accuracy: 0.9511 - val_loss: 0.1665
# Epoch 16/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9947 - loss: 0.0159 - val_accuracy: 0.9741 - val_loss: 0.0920
# Epoch 17/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9951 - loss: 0.0150 - val_accuracy: 0.9836 - val_loss: 0.0534
# Epoch 18/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9949 - loss: 0.0166 - val_accuracy: 0.9886 - val_loss: 0.0368
# Epoch 19/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9962 - loss: 0.0111 - val_accuracy: 0.9694 - val_loss: 0.1227
# Epoch 20/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9953 - loss: 0.0142 - val_accuracy: 0.9912 - val_loss: 0.0266
# Epoch 21/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9963 - loss: 0.0113 - val_accuracy: 0.9868 - val_loss: 0.0458
# Epoch 22/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9958 - loss: 0.0123 - val_accuracy: 0.9901 - val_loss: 0.0298
# Epoch 23/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9969 - loss: 0.0104 - val_accuracy: 0.9791 - val_loss: 0.0677
# Epoch 24/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9965 - loss: 0.0100 - val_accuracy: 0.9824 - val_loss: 0.0655
# Epoch 25/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9975 - loss: 0.0087 - val_accuracy: 0.9910 - val_loss: 0.0339
# Epoch 26/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9967 - loss: 0.0099 - val_accuracy: 0.9826 - val_loss: 0.0663
# Epoch 27/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9967 - loss: 0.0099 - val_accuracy: 0.9707 - val_loss: 0.1176
# Epoch 28/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9973 - loss: 0.0086 - val_accuracy: 0.9672 - val_loss: 0.1284
# Epoch 29/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9968 - loss: 0.0094 - val_accuracy: 0.9846 - val_loss: 0.0508
# Epoch 30/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9971 - loss: 0.0085 - val_accuracy: 0.9833 - val_loss: 0.0583
# Epoch 31/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9972 - loss: 0.0083 - val_accuracy: 0.9877 - val_loss: 0.0451
# Epoch 32/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9980 - loss: 0.0061 - val_accuracy: 0.9900 - val_loss: 0.0323
# Epoch 33/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9981 - loss: 0.0057 - val_accuracy: 0.9796 - val_loss: 0.0894
# Epoch 34/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9971 - loss: 0.0089 - val_accuracy: 0.9891 - val_loss: 0.0413
# Epoch 35/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9976 - loss: 0.0070 - val_accuracy: 0.9778 - val_loss: 0.0936
# Epoch 36/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9984 - loss: 0.0050 - val_accuracy: 0.9870 - val_loss: 0.0464
# Epoch 37/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9975 - loss: 0.0075 - val_accuracy: 0.9817 - val_loss: 0.0663
# Epoch 38/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9981 - loss: 0.0058 - val_accuracy: 0.9877 - val_loss: 0.0474
# Epoch 39/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.9909 - val_loss: 0.0322
# Epoch 40/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9980 - loss: 0.0059 - val_accuracy: 0.9918 - val_loss: 0.0302
# Epoch 41/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9978 - loss: 0.0062 - val_accuracy: 0.9895 - val_loss: 0.0396
# Epoch 42/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9982 - loss: 0.0053 - val_accuracy: 0.9894 - val_loss: 0.0423
# Epoch 43/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9984 - loss: 0.0049 - val_accuracy: 0.9913 - val_loss: 0.0341
# Epoch 44/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9984 - loss: 0.0045 - val_accuracy: 0.9902 - val_loss: 0.0407
# Epoch 45/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9976 - loss: 0.0059 - val_accuracy: 0.9889 - val_loss: 0.0443
# Epoch 46/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9982 - loss: 0.0048 - val_accuracy: 0.9905 - val_loss: 0.0350
# Epoch 47/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9987 - loss: 0.0036 - val_accuracy: 0.9831 - val_loss: 0.0687
# Epoch 48/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9983 - loss: 0.0062 - val_accuracy: 0.9904 - val_loss: 0.0334
# Epoch 49/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.9883 - val_loss: 0.0469
# Epoch 50/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9984 - loss: 0.0052 - val_accuracy: 0.9858 - val_loss: 0.0640
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9830 - loss: 0.0829
# Точность модели на тестовых данных: 0.9858

# %% [markdown]
# Очистим память

# %%
del x_train
del y_train
del x_test
del y_test

gc.collect()
# Out:
# 1038

# %% [markdown]
# **Задание 2.** После уточнения модели на синтетических данных попробуйте обучить ее на реальных данных (набор Google Street View). Что изменилось в модели?

# %% [markdown]
# Загрузим набор тестовых данных `SVHN` (Street View House Numbers)

# %%
# Загружаем train
train = loadmat('train_32x32.mat')
x_train = np.transpose(train['X'], (3, 0, 1, 2)).astype(np.float32) / 255.0
y_train = train['y'].astype(np.uint8).flatten()
y_train[y_train == 10] = 0
del train
gc.collect()  # принудительная сборка мусора

# Загружаем test
test = loadmat('test_32x32.mat')
x_test = np.transpose(test['X'], (3, 0, 1, 2)).astype(np.float32) / 255.0
y_test = test['y'].astype(np.uint8).flatten()
y_test[y_test == 10] = 0
del test
gc.collect()
# Out:
# 0

# %% [markdown]
# Преобразуем изображения оригинальные изображения (32x32, цветные) в черно-белые и уменьшим их размер до 28x28

# %%
x_train = tf.image.rgb_to_grayscale(x_train).numpy()
x_test = tf.image.rgb_to_grayscale(x_test).numpy()

x_train = tf.image.resize(x_train, [28, 28]).numpy()
x_test = tf.image.resize(x_test, [28, 28]).numpy()

# %% [markdown]
# Дообучим модель на новых данных

# %%
model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test))
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Точность модели на тестовых данных: {test_acc:.4f}')
# Out:
# Epoch 1/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - accuracy: 0.4490 - loss: 1.9078 - val_accuracy: 0.7011 - val_loss: 0.9297
# Epoch 2/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.7485 - loss: 0.7993 - val_accuracy: 0.7266 - val_loss: 0.8625
# Epoch 3/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.7991 - loss: 0.6328 - val_accuracy: 0.7955 - val_loss: 0.6402
# Epoch 4/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 26s 12ms/step - accuracy: 0.8269 - loss: 0.5518 - val_accuracy: 0.8541 - val_loss: 0.4754
# Epoch 5/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.8479 - loss: 0.4949 - val_accuracy: 0.8266 - val_loss: 0.5634
# Epoch 6/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.8593 - loss: 0.4537 - val_accuracy: 0.8820 - val_loss: 0.3964
# Epoch 7/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.8710 - loss: 0.4206 - val_accuracy: 0.8672 - val_loss: 0.4231
# Epoch 8/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.8789 - loss: 0.3941 - val_accuracy: 0.8633 - val_loss: 0.4525
# Epoch 9/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.8870 - loss: 0.3767 - val_accuracy: 0.8888 - val_loss: 0.3688
# Epoch 10/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - accuracy: 0.8889 - loss: 0.3607 - val_accuracy: 0.8791 - val_loss: 0.3882
# Epoch 11/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.8954 - loss: 0.3470 - val_accuracy: 0.8950 - val_loss: 0.3500
# Epoch 12/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.8977 - loss: 0.3328 - val_accuracy: 0.8845 - val_loss: 0.3797
# Epoch 13/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9013 - loss: 0.3229 - val_accuracy: 0.8774 - val_loss: 0.4048
# Epoch 14/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9050 - loss: 0.3136 - val_accuracy: 0.8874 - val_loss: 0.3702
# Epoch 15/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9063 - loss: 0.3060 - val_accuracy: 0.9035 - val_loss: 0.3274
# Epoch 16/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9090 - loss: 0.3005 - val_accuracy: 0.8932 - val_loss: 0.3565
# Epoch 17/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9137 - loss: 0.2881 - val_accuracy: 0.9084 - val_loss: 0.3184
# Epoch 18/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9146 - loss: 0.2851 - val_accuracy: 0.8775 - val_loss: 0.4097
# Epoch 19/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.9143 - loss: 0.2836 - val_accuracy: 0.8928 - val_loss: 0.3555
# Epoch 20/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9175 - loss: 0.2724 - val_accuracy: 0.9087 - val_loss: 0.3072
# Epoch 21/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.9201 - loss: 0.2649 - val_accuracy: 0.8945 - val_loss: 0.3515
# Epoch 22/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9196 - loss: 0.2701 - val_accuracy: 0.9025 - val_loss: 0.3268
# Epoch 23/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9206 - loss: 0.2623 - val_accuracy: 0.9108 - val_loss: 0.3065
# Epoch 24/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9223 - loss: 0.2593 - val_accuracy: 0.8983 - val_loss: 0.3444
# Epoch 25/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9240 - loss: 0.2543 - val_accuracy: 0.9073 - val_loss: 0.3072
# Epoch 26/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9257 - loss: 0.2483 - val_accuracy: 0.9105 - val_loss: 0.3026
# Epoch 27/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9248 - loss: 0.2450 - val_accuracy: 0.9139 - val_loss: 0.2921
# Epoch 28/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.9266 - loss: 0.2444 - val_accuracy: 0.9122 - val_loss: 0.2980
# Epoch 29/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9265 - loss: 0.2417 - val_accuracy: 0.9115 - val_loss: 0.3009
# Epoch 30/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.9290 - loss: 0.2371 - val_accuracy: 0.9187 - val_loss: 0.2800
# Epoch 31/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9322 - loss: 0.2276 - val_accuracy: 0.9175 - val_loss: 0.2904
# Epoch 32/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.9302 - loss: 0.2327 - val_accuracy: 0.9062 - val_loss: 0.3210
# Epoch 33/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9332 - loss: 0.2253 - val_accuracy: 0.9115 - val_loss: 0.3033
# Epoch 34/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9321 - loss: 0.2268 - val_accuracy: 0.9174 - val_loss: 0.2853
# Epoch 35/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9345 - loss: 0.2184 - val_accuracy: 0.9090 - val_loss: 0.3203
# Epoch 36/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9348 - loss: 0.2183 - val_accuracy: 0.9159 - val_loss: 0.2912
# Epoch 37/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9347 - loss: 0.2169 - val_accuracy: 0.9081 - val_loss: 0.3148
# Epoch 38/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9364 - loss: 0.2117 - val_accuracy: 0.9094 - val_loss: 0.3094
# Epoch 39/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.9371 - loss: 0.2119 - val_accuracy: 0.9007 - val_loss: 0.3420
# Epoch 40/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9366 - loss: 0.2108 - val_accuracy: 0.9014 - val_loss: 0.3444
# Epoch 41/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9368 - loss: 0.2073 - val_accuracy: 0.9128 - val_loss: 0.3055
# Epoch 42/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9370 - loss: 0.2091 - val_accuracy: 0.9080 - val_loss: 0.3295
# Epoch 43/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9388 - loss: 0.2006 - val_accuracy: 0.8974 - val_loss: 0.3546
# Epoch 44/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9390 - loss: 0.1998 - val_accuracy: 0.9118 - val_loss: 0.3074
# Epoch 45/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9390 - loss: 0.1996 - val_accuracy: 0.9118 - val_loss: 0.3131
# Epoch 46/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.9401 - loss: 0.2001 - val_accuracy: 0.9125 - val_loss: 0.3070
# Epoch 47/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.9416 - loss: 0.1926 - val_accuracy: 0.9100 - val_loss: 0.3158
# Epoch 48/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.9437 - loss: 0.1887 - val_accuracy: 0.9084 - val_loss: 0.3292
# Epoch 49/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.9425 - loss: 0.1887 - val_accuracy: 0.9014 - val_loss: 0.3470
# Epoch 50/50
# 2290/2290 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - accuracy: 0.9411 - loss: 0.1915 - val_accuracy: 0.9133 - val_loss: 0.3097
# 814/814 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9156 - loss: 0.3084
# Точность модели на тестовых данных: 0.9133

# %% [markdown]
# Сохраним модель

# %%
model.export("saved_model/resnet_model")
# Out:
# INFO:tensorflow:Assets written to: saved_model/resnet_model/assets
# INFO:tensorflow:Assets written to: saved_model/resnet_model/assets
# Saved artifact at 'saved_model/resnet_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28, 28, 1), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   138427581809872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581811216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581813520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581812176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581812368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581811024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581813328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581813904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581814480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581815440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581816592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581815632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581816400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581812752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581821392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581821968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581816208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581819280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581819856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581816016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581819664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581818320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581822160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581821008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581818512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581821776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581823696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581824272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581820240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138427581824656: TensorSpec(shape=(), dtype=tf.resource, name=None)
